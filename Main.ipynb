# %%
import importlib
import BudgetProfile
import User
import Expense
import Screen
import BudgetAgent
import ipywidgets as widgets
from IPython.display import display, clear_output

importlib.reload(BudgetProfile)
importlib.reload(User)
importlib.reload(Screen)
importlib.reload(Expense)
# Out:
# <module 'Expense' from 'c:\\Users\\nicol\\projects\\Final\\Expense.py'>

# %%
Screen.start_screen()
